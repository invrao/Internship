# %% [markdown]
# # Q1 Write a python program which searches all the product under a particular product from www.amazon.in. The product to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search for guitars.

# %%
#importing required libraries
import selenium
import pandas as pd
import time
import warnings
warnings.filterwarnings("ignore")
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import requests
import re

# %%
#connecting to the webdriver
driver=webdriver.Edge(r"C:\Users\invra\Downloads\edgedriver_win64\msedgedriver.exe")

# %%
#maximizing the window
driver.maximize_window()

# %%
#opening the amazon website on automated edge browser
driver.get("https://www.amazon.in/")

time.sleep(3)

# %%
#Asking the user for the search input
search=input("Enter keyword, you wanted to search on Amazon.in website:")
# Out:
# Enter keyword, you wanted to search on Amazon.in website:Guitar

# %%
#entering the search word as per requirement
searching=driver.find_element(By.XPATH,'//*[@id="twotabsearchtextbox"]')
searching.send_keys(search)

# %%
#clicking on search button
clicking=driver.find_element(By.XPATH,'//*[@id="nav-search-submit-button"]')
clicking.click()

# %% [markdown]
# #  Q2  In the above question, now scrape the following details of each product listed in first 3 pages of your search results and save it in a data frame and csv. In case if any product has less than 3 pages in search results then scrape all the products available under that product name. Details to be scraped are: "Brand Name", "Name of the Product", "Price", "Return/Exchange", "Expected Delivery", "Availability" and “Product URL”. In case, if any of the details are missing for any of the product then replace it by “-“.

# %%
# fetching URLs to open the pages
urls = []          # empty list
for i in range(0,3):      # for loop to scrape 3 pages
    page_url = driver.find_elements(By.XPATH,'//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')
    for i in page_url:
        urls.append(i.get_attribute("href"))
    next_btn = driver.find_element(By.XPATH,'//a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]')
    time.sleep(3)

# %%
len(urls)
# Out:
# 210

# %%
#Creating the empty lists for saving the details to list
Brand_Name=[]
Name_of_Product=[]
Price=[]
Return_Exchange=[]
Expected_Delivery=[]
Availability=[]

#using for loop to get the details of all the guitars from their URLs
for i in urls:
    driver.get(i)
    time.sleep(1)
    
    #to fetch the Brand Names
    try:
        brand=driver.find_element(By.XPATH,'//tr[@class="a-spacing-small po-brand"]')
        Brand_Name.append(brand.text)
    except NoSuchElementException:
        Brand_Name.append('-')
        
    #to fetch the product names   
    try:
        product=driver.find_element(By.XPATH,'//span[@class="a-size-large product-title-word-break"]')
        Name_of_Product.append(product.text)
    except NoSuchElementException:
        Name_of_Product.append('-')
        
    
    #to fetch the prices
    try:
        Prices=driver.find_element(By.XPATH,'//span[@class="a-price aok-align-center reinventPricePriceToPayMargin priceToPay"]')
        Price.append(Prices.text)
    except NoSuchElementException:
        Price.append('-')
        
    
    #to fetch the return or exhange policy
    try:
        Return=driver.find_element(By.XPATH,'//*[@id="RETURNS_POLICY"]/span/div[2]/a')
        Return_Exchange.append(Return.text)
    except NoSuchElementException:
        Return_Exchange.append('-')
        
    
    #to fetch the delivery time
    try:
        delivery=driver.find_element(By.XPATH,'//*[@id="mir-layout-DELIVERY_BLOCK-slot-PRIMARY_DELIVERY_MESSAGE_LARGE"]/span/span[1]')
        Expected_Delivery.append(delivery.text)
    except NoSuchElementException:
        Expected_Delivery.append('-')
        
    
    #to fetch the stock availability
    try:
        stock=driver.find_element(By.XPATH,'//*[@id="availability"]/span')
        Availability.append(stock.text)
    except NoSuchElementException:
        Availability.append('-')

# %%
#to check the content length of each of the lists
len(Brand_Name),len(Name_of_Product),len(Price),len(Return_Exchange),len(Expected_Delivery),len(Availability)
# Out:
# (210, 210, 210, 210, 210, 210)

# %%
Guitar=pd.DataFrame({"Brand_Name":Brand_Name,"Name_of_Product":Name_of_Product,"Price":Price,"Return/Exchange":Return_Exchange,"Expected Delivery":Expected_Delivery,"Availability":Availability})
Guitar
# Out:
#                   Brand_Name  \
# 0              Brand Kadence
# 1             Brand Medellin
# 2              Brand Kadence
# 3             Brand Medellin
# 4               Brand Juârez
# ..                       ...
# 205              Brand VAULT
# 206  Brand DIKUJI ENTERPRISE
# 207          Brand blueberry
# 208         Brand Guitar Bro
# 209             Brand FESTRA
#
#                                        Name_of_Product   Price  \
# 0    Kadence Frontier guitar with Online Guitar lea...  ₹4,949
# 1    Medellin M38 carbon fiber body 38 Incheses Aco...  ₹2,428
# 2    Kadence Slowhand Premium Jumbo Semi Acoustic G...  ₹9,900
# 3    Medellin 38" Acoustic Guitar premium wood with...  ₹2,398
# 4    Juârez Acoustic Guitar, 38 Inch Cutaway, 038C ...  ₹2,149
# ..                                                 ...     ...
# 205     Vault CL-20 4/4 size Classical Guitar With Bag  ₹4,799
# 206  DIKUJI ENTERPRISE Plastic Medium Acoustic Guit...    ₹999
# 207  Blueberry 38C, 38" Acoustic Guitar Kit with Ba...  ₹2,695
# 208  GUITAR BRO - COMBO (Black Acoustic Guitar for ...  ₹8,999
# 209  Festra R-40-Natural Acoustic Guitar Kit with B...  ₹4,495
#
#         Return/Exchange        Expected Delivery Availability
# 0    7 days Replacement     Tuesday, 27 December
# 1    7 days Replacement    Thursday, 29 December    In stock.
# 2    7 days Replacement    Thursday, 29 December
# 3     7 days Returnable    Saturday, 31 December    In stock.
# 4    7 days Replacement      Friday, 30 December    In stock.
# ..                  ...                      ...          ...
# 205  7 days Replacement    Thursday, 29 December    In stock.
# 206  7 days Replacement    Saturday, 31 December    In stock.
# 207  7 days Replacement    Saturday, 31 December    In stock.
# 208  7 days Replacement  December 30 - January 2    In stock.
# 209  7 days Replacement    Saturday, 31 December    In stock.
#
# [210 rows x 6 columns]

# %%
Guitar.to_csv('Guitar.csv')
driver.close()

# %% [markdown]
# # Q3.Write a python program to access the search bar and search button on images.google.com and scrape 10 images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’, ‘Guitar’, ‘Cakes’.

# %%
#importing required libraries
import selenium
import pandas as pd
import time
import warnings
warnings.filterwarnings("ignore")
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import requests
import re

# %%
#connecting to the webdriver
driver=webdriver.Edge(r"C:\Users\invra\Downloads\edgedriver_win64\msedgedriver.exe")

# %%
#maximizing the window
driver.maximize_window()

# %%
#opening the images.google.com website on automated edge browser
driver.get("https://images.google.com/")

time.sleep(3)

# %%
List_KeyWords=("fruits","cars","Machine Learning","Guitar","Cakes")

# %%
List_KeyWords
# Out:
# ('fruits', 'cars', 'Machine Learning', 'Guitar', 'Cakes')

# %%
# geting the webpage of mentioned url
url = "http://images.google.com/"

# creating empty list
urls = []
data = []

search_item = ["Fruits","Cars","Machine Learning","Guitar","Cakes"]
for item in search_item:
    driver.get(url)
    time.sleep(3)
    
    # finding webelement for search_bar
    search_bar = driver.find_element(By.TAG_NAME,"input")
    
    # sending keys to get the keyword for search bar
    search_bar.send_keys(str(item))
    
    # clicking on search button
    search_button = driver.find_element(By.XPATH,"//button[@class='Tg7LZd']")
    search_button.click()
    
    # scroling down the webpage to get some more images
    for _ in range(500):
        driver.execute_script("window.scrollBy(0,100)")
        
        imgs = driver.find_elements(By.XPATH,"//img[@class='rg_i Q4LuWd']")
    img_url = []
    for image in imgs:
        source = image.get_attribute('src')
        if source is not None:
            if(source[0:4] == 'http'):
                img_url.append(source)
    for i in img_url[:10]:
        urls.append(i)
        
for i in range(len(urls)):
    if i >= 10:
        break
    print("Downloading {0} of {1} images" .format(i,10))
    response = requests.get(urls[i])
    
    file = open(r'C:\Users\invra\Untitled Folder'+str(i)+".jpg","wb")

    file.write(response.content)
# Out:
# Downloading 0 of 10 images
# Downloading 1 of 10 images
# Downloading 2 of 10 images
# Downloading 3 of 10 images
# Downloading 4 of 10 images
# Downloading 5 of 10 images
# Downloading 6 of 10 images
# Downloading 7 of 10 images
# Downloading 8 of 10 images
# Downloading 9 of 10 images

# %% [markdown]
# # Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on
# www.flipkart.com and scrape following details for all the search results displayed on 1st page. Details to be
# scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”,
# “Secondary Camera”, “Display Size”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the
# details is missing then replace it by “- “. Save your results in a dataframe and CSV.

# %%
#importing required libraries
import selenium
import pandas as pd
import time
import warnings
warnings.filterwarnings("ignore")
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By

# %%
#connecting to the webdriver
driver=webdriver.Edge(r"C:\Users\invra\Downloads\edgedriver_win64\msedgedriver.exe")

#maximizing the window
driver.maximize_window()

# %%
# getting the webpage of mentioned url
driver.get("https://www.flipkart.com/")

# %%
# closing login popup button
login = driver.find_element(By.XPATH,"/html/body/div[2]/div/div/button")
login.click()

# %%
#to search for One Plus Nord

search=driver.find_element(By.XPATH,'//input[@class="_3704LK"]')
search.send_keys("OnePlus Nord")

#clicking on the search icon
search_button=driver.find_element(By.XPATH,'//button[@class="L0Z3Pu"]')
search_button.click()

# %%
#to get the product UrLs of all the products listed in page 1
Product_URL=[]
URL=driver.find_elements(By.XPATH,'//a[@class="_1fQZEK"]')
for i in URL:
    Product_URL.append(i.get_attribute('href'))

# %%
len(Product_URL)
# Out:
# 24

# %%
#Creating empty lists for saving all the required details in to lists
Brand_Name=[]
Smartphone_Name=[]
Colour=[]
RAM=[]
Storage_ROM=[]
Primary_Camera=[]
Secondary_Camera=[]
Display_Size=[]
Battery_Capacity=[]
Price=[]


#fetaching the required details from each listed item from their URLS exctracted above

for i in Product_URL:
    driver.get(i) 
    #to click on the read more option to get all details to scrap
    read_more=driver.find_element(By.XPATH,'//button[@class="_2KpZ6l _1FH0tX"]')
    read_more.click()
    
    #to fetch the Brand Name
    try:
        Brand=driver.find_element(By.XPATH,'//span[@class="B_NuCI"]')
        Brand_Name.append(Brand.text.split()[0])
    except NoSuchElementException:
        Brand_Name.append('-')
        
        
    #to fetch smartPhone Name
    try:
        name_tags = driver.find_element(By.XPATH,"//div[@class='_3k-BhJ'][1]/table/tbody/tr[3]/td[2]/ul/li")
        Smartphone_Name.append(name_tags.text)
    except NoSuchElementException:
        Smartphone_Name.append('-')
        
    
    #to fetch phone colour option
    try:
        color=driver.find_element(By.XPATH,"//div[@class='_3k-BhJ'][1]/table/tbody/tr[4]/td[2]/ul/li")
        Colour.append(color.text)
    except NoSuchElementException:
        Colour.append('-')
        
        
    #to fetch RAM
    try:
        RAMs=driver.find_element(By.XPATH,"//div[@class='_3k-BhJ'][4]/table[1]/tbody/tr[2]/td[2]/ul/li")
        RAM.append(RAMs.text)
    except NoSuchElementException:
        RAM.append('-')
        
        
    #to fetch storage ROM
    try:
        ROM=driver.find_element(By.XPATH,"//div[@class='_3k-BhJ'][4]/table[1]/tbody/tr[1]/td[2]/ul/li")
        Storage_ROM.append(ROM.text)
    except NoSuchElementException:
        Storage_ROM.append('-')
        
        
        
    #to fetch Primary_Camera of the phone
    try:
        Pri_cam=driver.find_element(By.XPATH,"//div[@class='_3k-BhJ'][5]/table[1]/tbody/tr[2]/td[2]/ul/li")
        Primary_Camera.append(Pri_cam.text)
    except NoSuchElementException:
        Primary_Camera.append('-')
        
        
          
    # to fetch secondary camera of the phone
    try:
        sec = driver.find_element(By.XPATH,"//div[@class='_3k-BhJ'][5]/table[1]/tbody/tr[6]/td[1]")
        if sec != 'Secondary Camera' :
            if driver.find_element(By.XPATH,"//div[@class='_3k-BhJ'][5]/table[1]/tbody/tr[5]/td[1]").text == "Secondary Camera":
                sec_cam =driver.find_element(By.XPATH,"//div[@class='_3k-BhJ'][5]/table[1]/tbody/tr[5]/td[2]/ul/li")
            else :
                raise NoSuchElementException
        else :
            sec_cam = driver.find_element(By.XPATH,"//div[@class='_3k-BhJ'][5]/table[1]/tbody/tr[6]/td[2]/ul/li")
        Secondary_Camera.append(sec_cam.text)
    except NoSuchElementException:
        Secondary_Camera.append('-')
        
        
        
    #to fetch Display_Size
    try:
        disp = driver.find_element(By.XPATH,"//div[@class='_3k-BhJ'][2]/div")
        if disp.text != 'Display Features' : raise NoSuchElementException
        disp_size = driver.find_element(By.XPATH,"//div[@class='_3k-BhJ'][2]/table[1]/tbody/tr[1]/td[2]/ul/li")
        Display_Size.append(disp_size.text)
    except NoSuchElementException:
        Display_Size.append('-')
        
        
        
    #to fetch battery capacity
    try:
        if driver.find_element(By.XPATH,"//div[@class='_3k-BhJ'][10]/div").text != "Battery & Power Features" :
            if driver.find_element(By.XPATH,"//div[@class='_3k-BhJ'][9]/div").text == "Battery & Power Features" :
                bat_tags = driver.find_element(By.XPATH,"//div[@class='_3k-BhJ'][9]/table/tbody/tr/td[1]")
                if bat_tags.text != "Battery Capacity" : raise NoSuchElementException
                bat_capa = driver.find_element(By.XPATH,"//div[@class='_3k-BhJ'][9]/table/tbody/tr/td[2]/ul/li")
            elif driver.find_element(By.XPATH,"//div[@class='_3k-BhJ'][8]/div").text == "Battery & Power Features" :
                bat_tags = driver.find_element(By.XPATH,"//div[@class='_3k-BhJ'][8]/table/tbody/tr/td[1]")
                if bat_tags.text != "Battery Capacity" : raise NoSuchElementException
                bat_capa = driver.find_element(By.XPATH,"//div[@class='_3k-BhJ'][8]/table/tbody/tr/td[2]/ul/li")
            else:
                raise NoSuchElementException
        else :
            bat_tags = driver.find_element(By.XPATH,"//div[@class='_3k-BhJ'][10]/table/tbody/tr/td[1]")
            if bat_tags.text != "Battery Capacity" : raise NoSuchElementException
            bat_capa = driver.find_element(By.XPATH,"//div[@class='_3k-BhJ'][10]/table/tbody/tr/td[2]/ul/li")
        Battery_Capacity.append(bat_capa.text)
    except NoSuchElementException:
        Battery_Capacity.append('-')
        
        
        
    #to fetch price
    try:
        price_tags = driver.find_element(By.XPATH,"//div[@class='_30jeq3 _16Jk6d']")
        Price.append(price_tags.text)
    except NoSuchElementException:
        Price.append('-')

# %%
len(Brand_Name),len(Smartphone_Name),len(Colour),len(RAM),len(Storage_ROM),len(Primary_Camera),len(Secondary_Camera),len(Display_Size),len(Battery_Capacity),len(Price)
# Out:
# (24, 24, 24, 24, 24, 24, 24, 24, 24, 24)

# %%
#creating the pandas data frame
SmartPhones=pd.DataFrame({"Brand_Name":Brand_Name,"Smartphone_Name":Smartphone_Name,"Colour":Colour,"RAM":RAM,"Storage_ROM":Storage_ROM,"Primary_Camera":Primary_Camera,"Secondary_Camera":Secondary_Camera,"Display_Size":Display_Size,"Battery_Capacity":Battery_Capacity,"Price":Price})
SmartPhones
# Out:
#    Brand_Name    Smartphone_Name        Colour    RAM Storage_ROM  \
# 0     OnePlus  Nord CE 2 Lite 5G     Blue Tide   6 GB      128 GB
# 1     OnePlus  Nord CE 2 Lite 5G     Blue Tide   6 GB      128 GB
# 2     OnePlus  Nord CE 2 Lite 5G    Black Dusk   6 GB      128 GB
# 3     OnePlus     Nord CE 2 Lite    Black Dusk   6 GB      128 MB
# 4     OnePlus  Nord CE 2 Lite 5G     Blue Tide   6 GB      128 GB
# 5     OnePlus  Nord CE 2 Lite 5G    Black Dusk   6 GB      128 GB
# 6     OnePlus       Nord CE 2 5G   Bahama Blue   8 GB      128 GB
# 7     OnePlus         Nord CE 5G  Charcoal Ink   6 GB      128 GB
# 8     OnePlus          Nord 2 5G       PAC-MAN  12 GB      256 GB
# 9     OnePlus          Nord 2 5G   Gray Sierra  12 GB      256 GB
# 10    OnePlus          Nord 2 5G    Green Wood  12 GB      256 GB
# 11    OnePlus  Nord CE 2 Lite 5G    Black Dusk   6 GB      128 GB
# 12    OnePlus          Nord 2 5G   Gray Sierra   8 GB      128 GB
# 13    OnePlus         Nord 2T 5G      Jade Fog  12 GB      256 GB
# 14    OnePlus         Nord 2T 5G   Gray Shadow  12 GB      256 GB
# 15    OnePlus         Nord 2T 5G      Jade Fog   8 GB      128 GB
# 16    OnePlus         Nord 2T 5G      Jade Fog  12 GB      256 GB
# 17    OnePlus         Nord 2T 5G   Gray Shadow  12 GB      256 GB
# 18    OnePlus         Nord 2T 5G   Gray Shadow   8 GB      128 GB
# 19    OnePlus         Nord 2T 5G      Jade Fog  12 GB      256 GB
# 20    OnePlus               Nord     Gray Onyx  12 GB      256 GB
# 21    OnePlus               Nord     Gray Onyx   6 GB       64 GB
# 22    OnePlus               Nord   Blue Marble  12 GB      256 GB
# 23    OnePlus               Nord     Gray Onyx   8 GB      128 GB
#
#                 Primary_Camera   Secondary_Camera          Display_Size  \
# 0               Primary Camera                  -  16.74 cm (6.59 inch)
# 1   Primary & Secondary Camera                  -  16.74 cm (6.59 inch)
# 2   Primary & Secondary Camera                  -  16.74 cm (6.59 inch)
# 3               Primary Camera                  -  16.74 cm (6.59 inch)
# 4             64MP Rear Camera  16MP Front Camera  16.74 cm (6.59 inch)
# 5   Primary & Secondary Camera                  -  16.74 cm (6.59 inch)
# 6               Primary Camera                  -  16.33 cm (6.43 inch)
# 7               Primary Camera                  -  16.33 cm (6.43 inch)
# 8               Primary Camera                  -  16.33 cm (6.43 inch)
# 9               Primary Camera                  -  16.33 cm (6.43 inch)
# 10              Primary Camera                  -  16.33 cm (6.43 inch)
# 11  Primary & Secondary Camera                  -  16.74 cm (6.59 inch)
# 12              Primary Camera                  -  16.33 cm (6.43 inch)
# 13  Primary & Secondary Camera                  -   17.02 cm (6.7 inch)
# 14  Primary & Secondary Camera                  -  16.94 cm (6.67 inch)
# 15  Primary & Secondary Camera                  -   17.02 cm (6.7 inch)
# 16  Primary & Secondary Camera                  -   17.02 cm (6.7 inch)
# 17  Primary & Secondary Camera                  -   17.02 cm (6.7 inch)
# 18              Primary Camera                  -   17.02 cm (6.7 inch)
# 19              Primary Camera                  -   17.02 cm (6.7 inch)
# 20                  48MP + 8MP                  -  16.36 cm (6.44 inch)
# 21                  48MP + 8MP                  -  16.36 cm (6.44 inch)
# 22                  48MP + 8MP                  -  16.36 cm (6.44 inch)
# 23                  48MP + 8MP                  -  16.36 cm (6.44 inch)
#
#    Battery_Capacity    Price
# 0                 -  ₹19,950
# 1                 -  ₹19,950
# 2                 -  ₹19,890
# 3                 -  ₹19,885
# 4          5000 mAh  ₹19,999
# 5                 -  ₹19,949
# 6                 -  ₹24,998
# 7                 -  ₹20,899
# 8                 -  ₹37,900
# 9                 -  ₹34,499
# 10                -  ₹34,499
# 11                -  ₹19,999
# 12                -  ₹19,699
# 13                -  ₹33,999
# 14                -  ₹33,869
# 15                -  ₹28,999
# 16                -  ₹33,988
# 17                -  ₹33,860
# 18                -  ₹28,999
# 19                -  ₹33,999
# 20         4115 mAh  ₹29,999
# 21         4115 mAh  ₹24,999
# 22         4115 mAh  ₹29,999
# 23         4115 mAh  ₹27,999

# %%
# saving the data into a csv file
SmartPhones.to_csv("SmartPhones.csv")

# %%
driver.close()

# %% [markdown]
# # Q5 Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google maps.

# %%
#importing required libraries
import selenium
import pandas as pd
import time
import warnings
warnings.filterwarnings("ignore")
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import requests
import re

# %%
#connecting to the webdriver
driver=webdriver.Edge(r"C:\Users\invra\Downloads\edgedriver_win64\msedgedriver.exe")

# %%
#maximizing the window
driver.maximize_window()

# %%
#opening the maps.google.co.in website on automated edge browser
driver.get("https://www.google.co.in/maps")

time.sleep(3)

# %%
search_word=input("enter the search city name:")
search=driver.find_element(By.XPATH,'//input[@class="searchboxinput xiQnY"]')
search.send_keys(search_word)
button=driver.find_element(By.XPATH,'//button[@class="mL3xi"]')
button.click()
# Out:
# enter the search city name:visakhapatnam

# %%
try:
    url_string = driver.current_url
    print("URL Extracted: ", url_string)
    lat_long = re.findall(r'@(.*)data',url_string)
    if len(lat_long):
        lat_long_list = lat_long[0].split(",")
        if len(lat_long_list)>=2:
            latitude = lat_long_list[0]
            longitude = lat_long_list[1]
        print("Latitude = {}, Longitude = {}".format(latitude, longitude))
except Exception as e:
        print("Error: ", str(e))
# Out:
# URL Extracted:  https://www.google.co.in/maps/place/Visakhapatnam,+Andhra+Pradesh/@17.7384724,82.9817059,10z/data=!3m1!4b1!4m5!3m4!1s0x3a39431389e6973f:0x92d9c20395498468!8m2!3d17.6868159!4d83.2184815
# Latitude = 17.7384724, Longitude = 82.9817059

# %% [markdown]
# # Q6 Write a program to scrap details of all the funding deals for second quarter (i.e Jan 21 – March 21) from trak.in.

# %%
#importing required libraries
import selenium
import pandas as pd
import time
import warnings
warnings.filterwarnings("ignore")
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import requests
import re

# %%
#connecting to the webdriver
driver=webdriver.Edge(r"C:\Users\invra\Downloads\edgedriver_win64\msedgedriver.exe")

# %%
#maximizing the window
driver.maximize_window()

# %%
#opening the trak.in website on automated edge browser
driver.get("https://www.trak.in/")

time.sleep(3)

# %%
#to click on the funding deals option
funding=driver.find_element(By.XPATH,'//li[@class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-1237902"]')
funding.click()

# %%
#not getting data in funding deals option

# %% [markdown]
# # Q7.Write a program to scrap all the available details of best gaming laptops from digit.in.

# %%
#importing required libraries
import selenium
import pandas as pd
import time
import warnings
warnings.filterwarnings("ignore")
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import requests
import re
from selenium.webdriver.support.ui import WebDriverWait

# %%
#connecting to the webdriver
driver=webdriver.Edge(r"C:\Users\invra\Downloads\edgedriver_win64\msedgedriver.exe")

# %%
#maximizing the window
driver.maximize_window()

# %%
#opening the digit.in website on automated edge browser
driver.get("https://www.digit.in/")

time.sleep(3)

# %%
#for clicking on the best gaming laptops link
Gaming_Laptops=driver.find_element(By.XPATH,"/html/body/div[3]/div/div[2]/div[2]/div[4]/ul/li[9]")
Gaming_Laptops.click()

# %%
#creating empty lists and saving the deails to each list

#Laptop_Name=[]

#Name=driver.find_elements(By.TAG_NAME,'h3')
#for i in Name:
    #Laptop_Name.append(i.text)
    
#Laptop_Name
# Out:
# ['MSI Titan GT77-12UHS',
#  'Alienware X17 R2',
#  'Acer Predator Triton 500 SE PT516-52s',
#  'ASUS ROG Strix G17 G713RC-HX021W Ryzen 7-6800H (2022)',
#  'Omen By HP (16-B1371TX)',
#  'Acer Predator Helios 300 AN515-45',
#  'MSI Delta 15 (A5EFK-083IN)',
#  'Omen By HP (16-C0141AX)',
#  'Lenovo Legion 5i Pro (82RF00MGIN)',
#  'Alienware M15 R5 Ryzen Edition Icc-C780001win',
#  'Lenovo Slim 7 Gen 6 (82K8002JIN)']

# %%
# fetching URLs to open the pages
urls=[]          # empty list
    # for loop to scrape all the urls
laptop_url=driver.find_elements(By.XPATH,'//span[@class="datahreflink spec"]')
for i in laptop_url:
    urls.append(i.get_attribute("data-href"))

# %%
urls
# Out:
# ['https://www.digit.in/laptops/msi-titan-gt77-12uhs-12th-gen-core-i9-12900hx-2022-price-303891.html',
#  'https://www.digit.in/laptops/dell-new-alienware-x17-r2-d569944win9-12th-gen-core-i9-12900hk-2022-price-309253.html',
#  'https://www.digit.in/laptops/acer-predator-triton-500-se-pt516-52s-12th-gen-core-i7-12700h-2022-price-328956.html',
#  'https://www.digit.in/laptops/omen-by-hp-16-b1371tx-12th-gen-core-i7-12700h-2022-price-290829.html',
#  'https://www.digit.in/laptops/acer-nitro-5-an515-45-nh-qbrsi-007-ryzen-9-5900hx-2022-price-305725.html',
#  'https://www.digit.in/laptops/msi-delta-15-5th-gen-ryzen-9-5900hx-2022-price-288855.html',
#  'https://www.digit.in/laptops/hp-omen-16-c0141ax-ryzen-9-5900hx-2022-price-289331.html',
#  'https://www.digit.in/laptops/lenovo-legion-5-pro-82rf00mgin-12th-gen-core-i7-12700h-2022-price-311997.html',
#  'https://www.digit.in/laptops/dell-alienware-m15-r5-gaming-ryzen-r7-5800h-2022-price-288001.html',
#  'https://www.digit.in/laptops/lenovo-legion-s7-ryzen-7-5800h-2022-price-288281.html']

# %%
#creating empty lists for saving the details
Name=[]
Operating_System=[]
Display=[]
Processor=[]
Memory=[]
Release_Date=[]
Starting_Price=[]
Weight=[]
Rating=[]
Dimensions=[]

#using for loop to get the details of the each laptop
for i in urls:
    driver.get(i)
    time.sleep(3)
    
    #Scraping brand name 
    try:
        brand = driver.find_element(By.XPATH,"/html/body/div[3]/div[2]/div[2]/h1")
        Name.append(brand.text)
    except NoSuchElementException:
        Name.append('-')
    
    
    #Scraping the OS
    try:
        OS=driver.find_element(By.XPATH,'//*[@id="overview"]/div[2]/div[3]/div/ul/li[1]/div/p[2]/strong')
        Operating_System.append(OS.text)
    
    except NoSuchElementException:
        Operating_System.append('-')
        
        
    #Scraping Display
    try:
        Displays=driver.find_element(By.XPATH,'//*[@id="overview"]/div[2]/div[3]/div/ul/li[2]/div/p[2]/strong')
        Display.append(Displays.text)
        
    except NoSuchElementException:
        Display.append('-')
        
    #scraping the processor
    try:
        Proc=driver.find_element(By.XPATH,'//*[@id="overview"]/div[2]/div[3]/div/ul/li[3]/div/p[2]/strong')
        Processor.append(Proc.text)
        
    except NoSuchElementException:
        Processor.append('-')
        
    #Scraping Memory
    try:
        Mem=driver.find_element(By.XPATH,'//*[@id="overview"]/div[2]/div[3]/div/ul/li[4]/div/p[2]/strong')
        Memory.append(Mem.text)
        
    except NoSuchElementException:
        Memory.append('-')
        
     
    #scraping release year & Month
    try:
        Release=driver.find_element(By.XPATH,'//*[@id="overview"]/div[2]/div[1]/div[2]/strong')
        Release_Date.append(Release.text)
        
    except NoSuchElementException:
        Release_Date.append('NA')
        
    #scraping the price details   
    try:
        Prices=driver.find_element(By.XPATH,'//*[@id="overview"]/div[2]/div[4]/div/h2/strong')
        Starting_Price.append(Prices.text)
    
    except NoSuchElementException:
        Starting_Price.append('NA')
        
        
    #scraping weight
    try:
        weigh=driver.find_element(By.XPATH,'//*[@id="specs"]/div/div[1]/div[5]/table/tbody/tr[1]/td[3]')
        Weight.append(weigh.text)
        
    except NoSuchElementException:
        Weight.append('NA')
    

    #scraping rating
    try:
        Ratings=driver.find_element(By.XPATH,'//*[@id="user_review"]/div[3]/div[1]/div[1]/div')
        Rating.append(Ratings.text)
        
    except NoSuchElementException:
        Rating.append('NA')
        
        
    #Scraping Dimensions
    try:
        Dimen=driver.find_element(By.XPATH,'//*[@id="specs"]/div/div[1]/div[5]/table/tbody/tr[2]/td[3]')
        Dimensions.append(Dimen.text)
        
    except NoSuchElementException:
        Dimensions.append('NA')

# %%
#creating pandas data frame and saving the details to it

Top_Gaming_Laptops=pd.DataFrame({'Name':Name,'Release_Date':Release_Date,'Operating_System':Operating_System,'Display':Display,'Processor':Processor,'Memory':Memory,'Starting_Price':Starting_Price,'Weight':Weight,'Dimensions':Dimensions,'Rating':Rating})
Top_Gaming_Laptops
# Out:
#                                                 Name  Release_Date  \
# 0  MSI Titan GT77 12UHS 12th Gen Core i9-12900HX ...  14 Jul, 2022
# 1  Dell New Alienware x17 R2 D569944WIN9 12th Gen...  16 Aug, 2022
# 2  Acer Predator Triton 500 SE PT516-52s 12th Gen...  25 Oct, 2022
# 3  HP OMEN 16-B1371TX 12th Gen core i7-12700H (2022)  09 May, 2022
# 4  Acer Nitro 5 AN515-45 NH.QBRSI.007 Ryzen 9-590...  21 Jul, 2022
# 5         MSI Delta 15 5th Gen Ryzen 9-5900HX (2022)  14 Apr, 2022
# 6           HP Omen 16-C0141AX Ryzen 9 5900HX (2022)  19 Apr, 2022
# 7  Lenovo Legion 5 Pro 82RF00MGIN 12th Gen Core i...  05 Sep, 2022
# 8  DELL ALIENWARE M15 R5 GAMING Ryzen R7-5800H (2...  11 Apr, 2022
# 9   Lenovo Legion S7 82K800E8IN Ryzen 7-5800H (2022)  11 Apr, 2022
#
#   Operating_System              Display  \
# 0  Windows 11 Home  17.3" (3840 X 2160)
# 1  Windows 11 Home  17.3" (1920 X 1080)
# 2       Windows 11    16" (2560 X 1600)
# 3  Windows 11 Home  16.1" (2560 X 1440)
# 4  Windows 11 Home  15.6" (2560 X 1440)
# 5  Windows 11 Home  15.6" (1920 X 1080)
# 6  Windows 11 Home  16.1" (2560 X 1440)
# 7  Windows 11 Home    16" (2560 X 1600)
# 8  Windows 11 Home  15.6" (1920 X 1080)
# 9  Windows 11 Home         15.6 MP | NA
#
#                                  Processor                 Memory  \
# 0      12th Gen Intel Core I9-12900HX | NA    2 TB SSD/64 GB DDR5
# 1    12th Gen Intel Core I9-12900H | 5 GHz    1 TB SSD/32 GB DDR5
# 2  12th Gen Intel Core I7-12700H | 3.5 GHz    2 TB SSD/32 GB DDR5
# 3  12th Gen Intel Core I7-12700H | 4.7 GHz     1 TB SSD/8 GB DDR5
# 4                  AMD Ryzen 9-5900HX | NA  512 GB SSD/16 GB DDR4
# 5      AMD 5th Gen Ryzen 9-5900HX | 3.3GHz  1 TB SSD/16 GBGB DDR4
# 6            AMD Ryzen™ 9 5900HX | 3.3 GHz   1 TB NVMe/16 GB DDR4
# 7  12th Gen Intel Core I7-12700H | 2.3 GHz    1 TB SSD/16 GB DDR5
# 8            AMD Ryzen R7-5800H | 4.40 GHz  512 GB SSD/16 GB DDR4
# 9           Lenovo Ryzen 7-5800H | 3.2 GHz    1 TB SSD/16 GB DDR4
#
#   Starting_Price Weight             Dimensions Rating
# 0             NA    3.3         397 x 330 x 23    0/5
# 1      ₹ 389,990   2.96         299 x 359 x 21    0/5
# 2      ₹ 229,990    2.4         262 x 359 x 20    0/5
# 3      ₹ 176,490   2.32         369 x 248 x 23    0/5
# 4      ₹ 172,999    2.4       363 x 255 x 23.9    0/5
# 5      ₹ 188,990    1.9         357 x 247 x 19    0/5
# 6      ₹ 124,990    2.3     36.92 x 24.8 x 2.3    0/5
# 7      ₹ 163,236   2.49         360 x 264 x 20    0/5
# 8      ₹ 174,000   2.69  356.2 x 272.5 x 22.85    0/5
# 9      ₹ 131,990    1.9         356 x 252 x 16    0/5

# %%
Top_Gaming_Laptops.to_csv('Top_Gaming_Laptops.csv')
driver.close()

# %% [markdown]
# # Q8.Write a python program to scrape the details for all billionaires from www.forbes.com. Details to be scrapped: “Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”.

# %%
#importing required libraries
import selenium
import pandas as pd
import time
import warnings
warnings.filterwarnings("ignore")
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import requests
import re
from selenium.webdriver.support.ui import WebDriverWait

# %%
#connecting to the webdriver
driver=webdriver.Edge(r"C:\Users\invra\Downloads\edgedriver_win64\msedgedriver.exe")

# %%
#maximizing the window
driver.maximize_window()

# %%
#opening the forbes.com website on automated edge browser
driver.get("https://www.forbes.com/")

time.sleep(3)

# %%
#To click on the left side hamburger menu
menu=driver.find_element(By.XPATH,'//*[@id="globalHeaderMenu"]/div')
menu.click()
time.sleep(1)

# %%
#To click on the nillionaires option
option=driver.find_element(By.XPATH,'//*[@id="globalHeaderMenu"]/div/div[2]/ul/li[1]/div[1]')
option.click()
time.sleep(1)

# %%
#to click view all billionaires (worlds billionaires) option
allb=driver.find_element(By.XPATH,'//*[@id="row-1"]/div/div/div[1]/div/div[1]/div[1]/div[2]/a/h2')
allb.click()

# %%
#Creating empty lists
Rank=[]
Name=[]
NetWorth=[]
Age=[]
Citizenship=[]
Source=[]
Industry=[]

#Using for loop to scrap the all 14 pages

for i in range(14):
    
    #to get the Ranks of the billionaires scraped
    Ranks=driver.find_elements(By.XPATH,'//div[@class="rank"]')
    for i in Ranks:
        Rank.append(i.text)
        
    #to get the names of the billionaires scraped
    Names=driver.find_elements(By.XPATH,'//div[@class="personName"]')
    for i in Names:
        Name.append(i.text)
        
    #to get the Networth
    NetWorths=driver.find_elements(By.XPATH,'//div[@class="netWorth"]')
    for i in NetWorths:
        NetWorth.append(i.text)
        
    #to get the Age 
    Ages=driver.find_elements(By.XPATH,'//div[@class="age"]')
    for i in Ages:
        Age.append(i.text)
        
    #to get the citizenship details
    Citi=driver.find_elements(By.XPATH,'//div[@class="countryOfCitizenship"]')
    for i in Citi:
        Citizenship.append(i.text)
        
    #to get the source details
    sources=driver.find_elements(By.XPATH,'//div[@class="source-column"]')
    for i in sources:
        Source.append(i.text)
        
    #to get the Industry details
    Industries=driver.find_elements(By.XPATH,'//div[@class="category"]')
    for i in Industries:
        Industry.append(i.text)
    
#time.sleep(3)

#going to next page
Next_Page=driver.find_element(By.XPATH,'//*[@id="gatsby-focus-wrapper"]/div/div[2]/div[3]/div[2]/div[2]/div[2]/div[27]/div[2]/div[6]/div[1]/button[2]/div/span')
Next_Page.click()

# %%
len(Rank),len(Name),len(NetWorth),len(Age),len(Citizenship),len(Source),len(Industry)
# Out:
# (2800, 2800, 2800, 2800, 2800, 2800, 2800)

# %%
#creating pandas data frame and saving the data
Billionaires=pd.DataFrame({"Rank":Rank,"Name":Name,"NetWorth":NetWorth,"Age":Age,"Citizenship":Citizenship,"Source":Source,"Industry":Industry})
Billionaires
# Out:
#       Rank                      Name NetWorth Age    Citizenship  \
# 0       1.                 Elon Musk   $219 B  50  United States
# 1       2.                Jeff Bezos   $171 B  58  United States
# 2       3.  Bernard Arnault & family   $158 B  73         France
# 3       4.                Bill Gates   $129 B  66  United States
# 4       5.            Warren Buffett   $118 B  91  United States
# ...    ...                       ...      ...  ..            ...
# 2795  192.    Marcel Herrmann Telles  $10.3 B  72         Brazil
# 2796  197.                Leon Black    $10 B  70  United States
# 2797  197.                Joe Gebbia    $10 B  40  United States
# 2798  197.              David Geffen    $10 B  79  United States
# 2799  197.                Yu Renrong    $10 B  56          China
#
#                      Source               Industry
# 0             Tesla, SpaceX             Automotive
# 1                    Amazon             Technology
# 2                      LVMH       Fashion & Retail
# 3                 Microsoft             Technology
# 4        Berkshire Hathaway  Finance & Investments
# ...                     ...                    ...
# 2795                   beer        Food & Beverage
# 2796         private equity  Finance & Investments
# 2797                 Airbnb             Technology
# 2798  movies, record labels  Media & Entertainment
# 2799         semiconductors          Manufacturing
#
# [2800 rows x 7 columns]

# %%
Billionaires.to_csv('Billionaires.csv')
driver.close()

# %% [markdown]
# # Q9.Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted from any YouTube Video.

# %%
#importing required libraries
import selenium
import pandas as pd
import time
import warnings
warnings.filterwarnings("ignore")
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import requests
import re
from selenium.webdriver.support.ui import WebDriverWait

# %%
#connecting to the webdriver
driver=webdriver.Edge(r"C:\Users\invra\Downloads\edgedriver_win64\msedgedriver.exe")

# %%
#maximizing the window
driver.maximize_window()

# %%
#opening the youtube.com website on automated edge browser
driver.get("https://www.youtube.com/")

time.sleep(3)

# %%
#entering search term for a video
search=driver.find_element(By.XPATH,'//div[@class="ytd-searchbox-spt"]/input')
search.send_keys('GOT')

#clicking on search button
button=driver.find_element(By.ID,'search-icon-legacy')
button.click()

# %%
#clicking on the first video
video=driver.find_element(By.XPATH,'//yt-formatted-string[@class="style-scope ytd-video-renderer"]')
video.click()

# %%
# 10000 times we scroll down by 10000 in order to generate more comments
for _ in range(1000):
    driver.execute_script("window.scrollBy(0,10000)")

# %%
#make empty lists
comments = []
comment_time = []
Time = []
Likes = []
No_of_Likes = []

# %%
#scraping the data of comments
cm_tags = driver.find_elements(By.XPATH,'//*[@id="content-text"]')
for cm in cm_tags:
    if cm.text is None:
        comments.append("--")
    else:
        comments.append(cm.text)
time.sleep(5)

# %%
# scraping the data of time when comment was posted
tm_tags = driver.find_elements(By.XPATH,"//a[contains(text(),'ago')]")
for tm in tm_tags:
    Time.append(tm.text)

for i in range(0,len(Time),2):
    comment_time.append(Time[i])
time.sleep(8)

# %%
# scraping the data of comment likes
like_tags = driver.find_elements(By.XPATH,"//span[@class='style-scope ytd-comment-action-buttons-renderer']")
for like in like_tags:
    Likes.append(like.text)
    
for i in range(1,len(Likes),2):
    No_of_Likes.append(Likes[i])
    
time.sleep(8)

# %%
len(No_of_Likes),len(comments),len(comment_time)
# Out:
# (1440, 720, 1200)

# %%
#Creating dataframe
Youtube=pd.DataFrame({})
Youtube['Comments'] = comments[0:500]
Youtube['Comment_time'] = comment_time[0:500]
Youtube['Comment upvotes'] = No_of_Likes[0:500]

# %%
Youtube
# Out:
#                                               Comments           Comment_time  \
# 0    That moment of Tirion trial is the most powerf...             1 year ago
# 1    It is amazing just how spectacular and perfect...  6 months ago (edited)
# 2    “A dragon is not a slave” \n\nI got chills whe...             1 year ago
# 3    I literally just noticed that even after Arya ...          10 months ago
# 4    The scene with Hodor was one of the most under...          11 months ago
# ..                                                 ...                    ...
# 495  I cried harder than Danny over the dragons… I ...            1 month ago
# 496  Hard Home, Season 5. Jon Snow looking back fro...           8 months ago
# 497  Always loved how Unsullied were still kind of ...           5 months ago
# 498        Tyrion was the best character in this show.           6 months ago
# 499  The immediate head whip from Missandei when Da...           7 months ago
#
#     Comment upvotes
# 0                1K
# 1               197
# 2               210
# 3              1.3K
# 4               681
# ..              ...
# 495              63
# 496              85
# 497             206
# 498             469
# 499               9
#
# [500 rows x 3 columns]

# %% [markdown]
# # Write a python program to scrape a data for all available Hostels from https://www.hostelworld.com/ in “London” location. You have to scrape hostel name, distance from city centre, ratings, total reviews, overall reviews, privates from price, dorms from price, facilities and property description.

# %%
#importing required libraries
import selenium
import pandas as pd
import time
import warnings
warnings.filterwarnings("ignore")
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import requests
import re
from selenium.webdriver.support.ui import WebDriverWait

# %%
#connecting to the webdriver
driver=webdriver.Edge(r"C:\Users\invra\Downloads\edgedriver_win64\msedgedriver.exe")

# %%
#maximizing the window
driver.maximize_window()

# %%
#opening the hostelworld.com website on automated edge browser
driver.get("https://www.hostelworld.com/")

time.sleep(3)

# %%
# locating the location search bar
search_bar = driver.find_element(By.XPATH,'//*[@id="search-input-field"]')

# entering London in search bar
search_bar.send_keys("London")

# %%
# select London
London = driver.find_element(By.XPATH,'//*[@id="predicted-search-results"]/li[2]')
#clicking on button
London.click()

# do click on Let's Go button
search_btn = driver.find_element(By.ID,'search-button')
search_btn.click()

# %%
#lets find required data
hostel_name = []
distance = []
pvt_prices = []
dorms_price = []
rating = []
reviews = []
over_all = []
facilities = []
description =[]
product_url = []

# %%
#Scraping the requered informations
for i in range(2):

    #fetching hostel name
    try:
        name = driver.find_elements(By.XPATH,"//h2[@class='title title-6']")
        for i in name:
            hostel_name.append(i.text)
    except NoSuchElementException:
        hostel_name.append('-')
    #fetching distance from city centre
    
    try:
        dist = driver.find_elements(By.XPATH,"//div[@class='subtitle body-3']//a//span[1]")
        for i in dist:
            distance.append(i.text.replace('Hostel - ',''))
    except NoSuchElementException:
        distance.append('-')
        
    for i in driver.find_elements(By.XPATH,"//div[@class='prices-col']"):
    #fetch privates from price
        try:
            pvt_price = driver.find_element(By.XPATH,"//a[@class='prices']//div[1]//div")
            pvt_prices.append(pvt_price.text)
        except NoSuchElementException:
            pvt_prices.append('-')
    #fetching dorms from price
    for i in driver.find_elements(By.XPATH,"//div[@class='prices-col']"):
        try:
            dorms = driver.find_element(By.XPATH,"//a[@class='prices']//div[2]//div")
            dorms_price.append(dorms.text)
        except NoSuchElementException:
            dorms_price.append('-')
            #fetching facilities
    try:
        fac1 = driver.find_elements(By.XPATH,"//div[@class='has-wifi']")
        fac2 = driver.find_elements(By.XPATH,"//div[@class='has-sanitation']")
        for i in fac1:
            for j in fac2:
                facilities.append(i.text +', '+ j.text )
    except NoSuchElementException:
        facilities.append('-')
    #lets fetch url of each hostel
    p_url = driver.find_elements(By.XPATH,"//div[@class='prices-col']//a[2]")
    for i in p_url:
        product_url.append(i.get_attribute('href'))

for i in product_url:
    driver.get(i)
    time.sleep(3)
    #lets click on show more button for description
    #try:
        #driver.find_element(By.XPATH,"//a[@class='toggle-content']").click()
        #time.sleep(5)
    #except NoSuchElementException:
        #pass
    #fetching ratings
    try:
        rat = driver.find_element(By.XPATH,"//div[@class='score orange big' or @class='score gray big']")
        rating.append(rat.text)
    except NoSuchElementException:
        rating.append('-')
    #fetching total reviews
        
    try:
        rws = driver.find_element(By.XPATH,"//div[@class='reviews']")
        reviews.append(rws.text.replace('Total Reviews',''))
    except NoSuchElementException:
        reviews.append('-')
        #fetch overall review
    try:
        overall_rw = driver.find_element(By.XPATH,"//div[@class='keyword']//span")
        over_all.append(overall_rw.text)
    except NoSuchElementException:
        over_all.append('-')
    #fetch property description 
    try:
        disc = driver.find_element(By.XPATH,"//div[@class='content']")
        description.append(disc.text)
    except NoSuchElementException:
        over_all.append('-')
        
try:        
    button=driver.find_element(By.XPATH,"//div[@class = 'pagination-item pagination-current' or @class='pagination-item']")
    button.click()
except NoSuchElementException:
    
    print("Done")
time.sleep(4)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [167], in <cell line: 48>()
#      46         product_url.append(i.get_attribute('href'))
#      48 for i in product_url:
# ---> 49     driver.get(i)
#      50     time.sleep(3)
#      51     #lets click on show more button for description
#      52     #try:
#      53         #driver.find_element(By.XPATH,"//a[@class='toggle-content']").click()
#    (...)
#      56         #pass
#      57     #fetching ratings
#
# File ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webdriver.py:455, in WebDriver.get(self, url)
#     451 def get(self, url: str) -> None:
#     452     """
#     453     Loads a web page in the current browser session.
#     454     """
# --> 455     self.execute(Command.GET, {"url": url})
#
# File ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webdriver.py:442, in WebDriver.execute(self, driver_command, params)
#     439     elif "sessionId" not in params:
#     440         params["sessionId"] = self.session_id
# --> 442 response = self.command_executor.execute(driver_command, params)
#     443 if response:
#     444     self.error_handler.check_response(response)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\remote_connection.py:294, in RemoteConnection.execute(self, command, params)
#     292 data = utils.dump_json(params)
#     293 url = f"{self._url}{path}"
# --> 294 return self._request(command_info[0], url, body=data)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\remote_connection.py:316, in RemoteConnection._request(self, method, url, body)
#     313     body = None
#     315 if self.keep_alive:
# --> 316     response = self._conn.request(method, url, body=body, headers=headers)
#     317     statuscode = response.status
#     318 else:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\urllib3\request.py:78, in RequestMethods.request(self, method, url, fields, headers, **urlopen_kw)
#      74     return self.request_encode_url(
#      75         method, url, fields=fields, headers=headers, **urlopen_kw
#      76     )
#      77 else:
# ---> 78     return self.request_encode_body(
#      79         method, url, fields=fields, headers=headers, **urlopen_kw
#      80     )
#
# File C:\ProgramData\Anaconda3\lib\site-packages\urllib3\request.py:170, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     167 extra_kw["headers"].update(headers)
#     168 extra_kw.update(urlopen_kw)
# --> 170 return self.urlopen(method, url, **extra_kw)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\urllib3\poolmanager.py:376, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     374     response = conn.urlopen(method, url, **kw)
#     375 else:
# --> 376     response = conn.urlopen(method, u.request_uri, **kw)
#     378 redirect_location = redirect and response.get_redirect_location()
#     379 if not redirect_location:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File C:\ProgramData\Anaconda3\lib\http\client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File C:\ProgramData\Anaconda3\lib\http\client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File C:\ProgramData\Anaconda3\lib\http\client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File C:\ProgramData\Anaconda3\lib\socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
#Creating dataframe
Hotels = pd.DataFrame({})
Hotels['Hostel_Name'] = hostel_name
Hotels['Distance fron city centre'] = distance
Hotels['Ratings'] = rating
Hotels['Total_reviews'] = reviews
Hotels['Overall Reviews'] = over_all
Hotels['Privates from price'] = pvt_prices
Hotels['Dorms from price'] = dorms_price
Hotels['Facilities'] = facilities[:60]
Hotels['Description'] = description

# %%
Hotels
# Out:
#                                 Hostel_Name Distance fron city centre Ratings  \
# 0               Wombat's City Hostel London    3.6km from city centre     8.9
# 1                  St Christopher's Village    1.8km from city centre     8.0
# 2                   Hostel One Notting Hill    5.5km from city centre     9.3
# 3                      Urbany Hostel London    5.4km from city centre     9.2
# 4                          Generator London      3km from city centre     7.7
# 5         Safestay London Elephant & Castle    1.7km from city centre     7.3
# 6               Smart Russell Square Hostel    2.6km from city centre     7.0
# 7                Smart Hyde Park Inn Hostel      5km from city centre     7.5
# 8   Safestay London Kensington Holland Park    5.9km from city centre     7.0
# 9                          NX London Hostel    6.1km from city centre     7.6
# 10                  Smart Camden Inn Hostel    4.4km from city centre     8.4
# 11       Destinations Hostels @ The Gallery    1.7km from city centre     9.4
# 12                           Phoenix Hostel    4.2km from city centre     7.0
# 13             St Christopher's Hammersmith    7.5km from city centre     7.7
# 14                       London Backpackers   11.9km from city centre     7.7
# 15              Dover Castle Hostel and Bar    1.7km from city centre     8.4
# 16              Smart Hyde Park View Hostel      5km from city centre     8.0
# 17                  Queen Elizabeth Chelsea    5.7km from city centre     7.1
# 18                 Barmy Badger Backpackers    5.5km from city centre     8.9
# 19                  Prime Backpackers Angel    3.6km from city centre     8.1
# 20  St Christopher's Inn - Liverpool Street    3.2km from city centre     8.2
# 21                  Saint James Backpackers    5.5km from city centre     7.6
# 22               St Christopher's Greenwich    7.6km from city centre     7.3
# 23          St Christopher's Shepherds Bush      7km from city centre     7.1
# 24     PubLove @ The Steam Engine, Waterloo    0.5km from city centre     8.0
# 25                       Strand Continental    1.3km from city centre     6.9
# 26      PubLove @ The White Ferry, Victoria    2.4km from city centre     7.7
# 27                       Book a Bed Hostels    6.9km from city centre     5.9
# 28       St Christopher's Oasis-Female Only    1.8km from city centre     7.9
# 29                            Selina Camden    5.5km from city centre     8.7
# 30              Wombat's City Hostel London    3.6km from city centre     8.9
# 31                 St Christopher's Village    1.8km from city centre     8.0
# 32                  Hostel One Notting Hill    5.5km from city centre     9.3
# 33                     Urbany Hostel London    5.4km from city centre     9.2
# 34                         Generator London      3km from city centre     7.7
# 35        Safestay London Elephant & Castle    1.7km from city centre     7.3
# 36              Smart Russell Square Hostel    2.6km from city centre     7.0
# 37               Smart Hyde Park Inn Hostel      5km from city centre     7.5
# 38  Safestay London Kensington Holland Park    5.9km from city centre     7.0
# 39                         NX London Hostel    6.1km from city centre     7.6
# 40                  Smart Camden Inn Hostel    4.4km from city centre     8.4
# 41       Destinations Hostels @ The Gallery    1.7km from city centre     9.4
# 42                           Phoenix Hostel    4.2km from city centre     7.0
# 43             St Christopher's Hammersmith    7.5km from city centre     7.7
# 44                       London Backpackers   11.9km from city centre     7.7
# 45              Dover Castle Hostel and Bar    1.7km from city centre     8.4
# 46              Smart Hyde Park View Hostel      5km from city centre     8.0
# 47                  Queen Elizabeth Chelsea    5.7km from city centre     7.1
# 48                 Barmy Badger Backpackers    5.5km from city centre     8.9
# 49                  Prime Backpackers Angel    3.6km from city centre     8.1
# 50  St Christopher's Inn - Liverpool Street    3.2km from city centre     8.2
# 51                  Saint James Backpackers    5.5km from city centre     7.6
# 52               St Christopher's Greenwich    7.6km from city centre     7.3
# 53          St Christopher's Shepherds Bush      7km from city centre     7.1
# 54     PubLove @ The Steam Engine, Waterloo    0.5km from city centre     8.0
# 55                       Strand Continental    1.3km from city centre     6.9
# 56      PubLove @ The White Ferry, Victoria    2.4km from city centre     7.7
# 57                       Book a Bed Hostels    6.9km from city centre     5.9
# 58       St Christopher's Oasis-Female Only    1.8km from city centre     7.9
# 59                            Selina Camden    5.5km from city centre     8.7
#
#    Total_reviews Overall Reviews Privates from price Dorms from price  \
# 0         14424         Fabulous             Rs13582  Rs5142.9 Rs4114
# 1         11776         Fabulous             Rs13582  Rs5142.9 Rs4114
# 2          1646           Superb             Rs13582  Rs5142.9 Rs4114
# 3           580           Superb             Rs13582  Rs5142.9 Rs4114
# 4          7297        Very Good             Rs13582  Rs5142.9 Rs4114
# 5          4738        Very Good             Rs13582  Rs5142.9 Rs4114
# 6          9848        Very Good             Rs13582  Rs5142.9 Rs4114
# 7          6453        Very Good             Rs13582  Rs5142.9 Rs4114
# 8          1402        Very Good             Rs13582  Rs5142.9 Rs4114
# 9          1427        Very Good             Rs13582  Rs5142.9 Rs4114
# 10         3001         Fabulous             Rs13582  Rs5142.9 Rs4114
# 11           94           Superb             Rs13582  Rs5142.9 Rs4114
# 12         3908        Very Good             Rs13582  Rs5142.9 Rs4114
# 13         4177        Very Good             Rs13582  Rs5142.9 Rs4114
# 14         4390        Very Good             Rs13582  Rs5142.9 Rs4114
# 15         2313         Fabulous             Rs13582  Rs5142.9 Rs4114
# 16         4649         Fabulous             Rs13582  Rs5142.9 Rs4114
# 17         3374        Very Good             Rs13582  Rs5142.9 Rs4114
# 18         1870         Fabulous             Rs13582  Rs5142.9 Rs4114
# 19          698         Fabulous             Rs13582  Rs5142.9 Rs4114
# 20          454         Fabulous             Rs13582  Rs5142.9 Rs4114
# 21         1856        Very Good             Rs13582  Rs5142.9 Rs4114
# 22         3290        Very Good             Rs13582  Rs5142.9 Rs4114
# 23          742        Very Good             Rs13582  Rs5142.9 Rs4114
# 24          349         Fabulous             Rs13582  Rs5142.9 Rs4114
# 25          923             Good             Rs13582  Rs5142.9 Rs4114
# 26          309        Very Good             Rs13582  Rs5142.9 Rs4114
# 27         1224           Rating             Rs13582  Rs5142.9 Rs4114
# 28          714        Very Good             Rs13582  Rs5142.9 Rs4114
# 29           42         Fabulous             Rs13582  Rs5142.9 Rs4114
# 30        14424         Fabulous             Rs13582  Rs5142.9 Rs4114
# 31        11776         Fabulous             Rs13582  Rs5142.9 Rs4114
# 32         1646           Superb             Rs13582  Rs5142.9 Rs4114
# 33          580           Superb             Rs13582  Rs5142.9 Rs4114
# 34         7297        Very Good             Rs13582  Rs5142.9 Rs4114
# 35         4738        Very Good             Rs13582  Rs5142.9 Rs4114
# 36         9848        Very Good             Rs13582  Rs5142.9 Rs4114
# 37         6453        Very Good             Rs13582  Rs5142.9 Rs4114
# 38         1402        Very Good             Rs13582  Rs5142.9 Rs4114
# 39         1427        Very Good             Rs13582  Rs5142.9 Rs4114
# 40         3001         Fabulous             Rs13582  Rs5142.9 Rs4114
# 41           94           Superb             Rs13582  Rs5142.9 Rs4114
# 42         3908        Very Good             Rs13582  Rs5142.9 Rs4114
# 43         4177        Very Good             Rs13582  Rs5142.9 Rs4114
# 44         4390        Very Good             Rs13582  Rs5142.9 Rs4114
# 45         2313         Fabulous             Rs13582  Rs5142.9 Rs4114
# 46         4649         Fabulous             Rs13582  Rs5142.9 Rs4114
# 47         3374        Very Good             Rs13582  Rs5142.9 Rs4114
# 48         1870         Fabulous             Rs13582  Rs5142.9 Rs4114
# 49          698         Fabulous             Rs13582  Rs5142.9 Rs4114
# 50          454         Fabulous             Rs13582  Rs5142.9 Rs4114
# 51         1856        Very Good             Rs13582  Rs5142.9 Rs4114
# 52         3290        Very Good             Rs13582  Rs5142.9 Rs4114
# 53          742        Very Good             Rs13582  Rs5142.9 Rs4114
# 54          349         Fabulous             Rs13582  Rs5142.9 Rs4114
# 55          923             Good             Rs13582  Rs5142.9 Rs4114
# 56          309        Very Good             Rs13582  Rs5142.9 Rs4114
# 57         1224           Rating             Rs13582  Rs5142.9 Rs4114
# 58          714        Very Good             Rs13582  Rs5142.9 Rs4114
# 59           42         Fabulous             Rs13582  Rs5142.9 Rs4114
#
#                                          Facilities  \
# 0   Free WiFi, Follows Covid-19 sanitation guidance
# 1   Free WiFi, Follows Covid-19 sanitation guidance
# 2   Free WiFi, Follows Covid-19 sanitation guidance
# 3   Free WiFi, Follows Covid-19 sanitation guidance
# 4   Free WiFi, Follows Covid-19 sanitation guidance
# 5   Free WiFi, Follows Covid-19 sanitation guidance
# 6   Free WiFi, Follows Covid-19 sanitation guidance
# 7   Free WiFi, Follows Covid-19 sanitation guidance
# 8   Free WiFi, Follows Covid-19 sanitation guidance
# 9   Free WiFi, Follows Covid-19 sanitation guidance
# 10  Free WiFi, Follows Covid-19 sanitation guidance
# 11  Free WiFi, Follows Covid-19 sanitation guidance
# 12  Free WiFi, Follows Covid-19 sanitation guidance
# 13  Free WiFi, Follows Covid-19 sanitation guidance
# 14  Free WiFi, Follows Covid-19 sanitation guidance
# 15  Free WiFi, Follows Covid-19 sanitation guidance
# 16  Free WiFi, Follows Covid-19 sanitation guidance
# 17  Free WiFi, Follows Covid-19 sanitation guidance
# 18  Free WiFi, Follows Covid-19 sanitation guidance
# 19  Free WiFi, Follows Covid-19 sanitation guidance
# 20  Free WiFi, Follows Covid-19 sanitation guidance
# 21  Free WiFi, Follows Covid-19 sanitation guidance
# 22  Free WiFi, Follows Covid-19 sanitation guidance
# 23  Free WiFi, Follows Covid-19 sanitation guidance
# 24  Free WiFi, Follows Covid-19 sanitation guidance
# 25  Free WiFi, Follows Covid-19 sanitation guidance
# 26  Free WiFi, Follows Covid-19 sanitation guidance
# 27  Free WiFi, Follows Covid-19 sanitation guidance
# 28  Free WiFi, Follows Covid-19 sanitation guidance
# 29  Free WiFi, Follows Covid-19 sanitation guidance
# 30  Free WiFi, Follows Covid-19 sanitation guidance
# 31  Free WiFi, Follows Covid-19 sanitation guidance
# 32  Free WiFi, Follows Covid-19 sanitation guidance
# 33  Free WiFi, Follows Covid-19 sanitation guidance
# 34  Free WiFi, Follows Covid-19 sanitation guidance
# 35  Free WiFi, Follows Covid-19 sanitation guidance
# 36  Free WiFi, Follows Covid-19 sanitation guidance
# 37  Free WiFi, Follows Covid-19 sanitation guidance
# 38  Free WiFi, Follows Covid-19 sanitation guidance
# 39  Free WiFi, Follows Covid-19 sanitation guidance
# 40  Free WiFi, Follows Covid-19 sanitation guidance
# 41  Free WiFi, Follows Covid-19 sanitation guidance
# 42  Free WiFi, Follows Covid-19 sanitation guidance
# 43  Free WiFi, Follows Covid-19 sanitation guidance
# 44  Free WiFi, Follows Covid-19 sanitation guidance
# 45  Free WiFi, Follows Covid-19 sanitation guidance
# 46  Free WiFi, Follows Covid-19 sanitation guidance
# 47  Free WiFi, Follows Covid-19 sanitation guidance
# 48  Free WiFi, Follows Covid-19 sanitation guidance
# 49  Free WiFi, Follows Covid-19 sanitation guidance
# 50  Free WiFi, Follows Covid-19 sanitation guidance
# 51  Free WiFi, Follows Covid-19 sanitation guidance
# 52  Free WiFi, Follows Covid-19 sanitation guidance
# 53  Free WiFi, Follows Covid-19 sanitation guidance
# 54  Free WiFi, Follows Covid-19 sanitation guidance
# 55  Free WiFi, Follows Covid-19 sanitation guidance
# 56  Free WiFi, Follows Covid-19 sanitation guidance
# 57  Free WiFi, Follows Covid-19 sanitation guidance
# 58  Free WiFi, Follows Covid-19 sanitation guidance
# 59  Free WiFi, Follows Covid-19 sanitation guidance
#
#                                           Description
# 0                      7 Dock Street, London, England
# 1            165 Borough High Street, London, England
# 2                 63 Prince's Square, London, England
# 3   48-49 Princes Square, Paddington, London, England
# 4   Compton Place, Off 37 Tavistock Place, WC1, Lo...
# 5              144-152 Walworth Road, London, England
# 6                 71 Guilford Street, London, England
# 7   48 - 50 Inverness Terrace, Bayswater, London, ...
# 8     Holland Park Ave, Holland Walk, London, England
# 9                 323 New Cross Road, London, England
# 10       55/57 Bayham Street, Camden, London, England
# 11           1 Lupus street, Pimlico, London, England
# 12                 6 Daventry Street, London, England
# 13  28, Hammersmith Broadway, Hammersmith, London,...
# 14  8/10 Queens Parade, Queens Road, Hendon Centra...
# 15             6a Great Dover Street, London, England
# 16        16 Leinster Terrace W2 3EU, London, England
# 17                   58 Bagleys Lane, London, England
# 18    17 Longridge Road, Earls Court, London, England
# 19      333 City Road, 333 City Road, London, England
# 20        52 Wilson Street, Finsbury, London, England
# 21                 21 Longridge Road, London, England
# 22  189 Greenwich High Road, Greenwich, London, En...
# 23  Belushis Bar, 13-15 Shepherds Bush Green., Lon...
# 24                   41-42 Cosser St, London, England
# 25                143 Strand, London, London, England
# 26    1a Sutherland Street, Victoria, London, England
# 27        86 Tanner's Hill, Deptford, London, England
# 28  163 Borough High Street, SE1 1HR, Southwark, L...
# 29      89 Chalk Farm Rd, Chalk Farm, London, England
# 30                     7 Dock Street, London, England
# 31           165 Borough High Street, London, England
# 32                63 Prince's Square, London, England
# 33  48-49 Princes Square, Paddington, London, England
# 34  Compton Place, Off 37 Tavistock Place, WC1, Lo...
# 35             144-152 Walworth Road, London, England
# 36                71 Guilford Street, London, England
# 37  48 - 50 Inverness Terrace, Bayswater, London, ...
# 38    Holland Park Ave, Holland Walk, London, England
# 39                323 New Cross Road, London, England
# 40       55/57 Bayham Street, Camden, London, England
# 41           1 Lupus street, Pimlico, London, England
# 42                 6 Daventry Street, London, England
# 43  28, Hammersmith Broadway, Hammersmith, London,...
# 44  8/10 Queens Parade, Queens Road, Hendon Centra...
# 45             6a Great Dover Street, London, England
# 46        16 Leinster Terrace W2 3EU, London, England
# 47                   58 Bagleys Lane, London, England
# 48    17 Longridge Road, Earls Court, London, England
# 49      333 City Road, 333 City Road, London, England
# 50        52 Wilson Street, Finsbury, London, England
# 51                 21 Longridge Road, London, England
# 52  189 Greenwich High Road, Greenwich, London, En...
# 53  Belushis Bar, 13-15 Shepherds Bush Green., Lon...
# 54                   41-42 Cosser St, London, England
# 55                143 Strand, London, London, England
# 56    1a Sutherland Street, Victoria, London, England
# 57        86 Tanner's Hill, Deptford, London, England
# 58  163 Borough High Street, SE1 1HR, Southwark, L...
# 59      89 Chalk Farm Rd, Chalk Farm, London, England
